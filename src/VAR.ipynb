# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from statsmodels.tsa.api import VAR
import yfinance as yf
from matplotlib import dates as dt
from numpy import linalg
import matplotlib.ticker as ticker
import matplotlib as mpl

# %% [markdown]
# # Sentiment Data

# %%
df_sentiment = pd.read_csv("../data/sentiment_daily_data.csv")
df_sentiment.index = pd.DatetimeIndex(df_sentiment["release_date"]).to_period("D")
df_sentiment = df_sentiment.drop('release_date', axis = 1)
df_sentiment
# Out:
#               AAPL_daily  AAPL_diff  AMZN_daily  AMZN_diff  BAC_daily  \
# release_date
# 2014-01-04        0.9747    -0.9876      0.9870        0.0     1.8862
# 2014-01-05        2.6382     1.6635      0.9870        0.0     0.9956
# 2014-01-06        2.6382     0.0000      0.9870        0.0     0.9956
# 2014-01-07       -0.2695    -2.9077      0.9870        0.0     2.9495
# 2014-01-08       -0.2695     0.0000      0.9870        0.0     0.9862
# ...                  ...        ...         ...        ...        ...
# 2020-02-09       33.1780     0.0000      4.5365        0.0     4.1556
# 2020-02-10       33.1780     0.0000      4.5365        0.0     4.1556
# 2020-02-11       33.1780     0.0000      4.5365        0.0     4.1556
# 2020-02-12       33.1780     0.0000      4.5365        0.0     4.1556
# 2020-02-13       33.1780     0.0000      4.5365        0.0     4.1556
#
#               BAC_diff  CVX_daily  CVX_diff  HD_daily  HD_diff  ...  \
# release_date                                                    ...
# 2014-01-04      0.0000     1.9993    0.0000    0.9900      0.0  ...
# 2014-01-05     -0.8906     1.9993    0.0000    0.9900      0.0  ...
# 2014-01-06      0.0000     1.9993    0.0000    0.9900      0.0  ...
# 2014-01-07      1.9539     1.9993    0.0000    0.9900      0.0  ...
# 2014-01-08     -1.9633     1.9993    0.0000    0.9900      0.0  ...
# ...                ...        ...       ...       ...      ...  ...
# 2020-02-09      0.0000     1.9594    0.7939    0.9975      0.0  ...
# 2020-02-10      0.0000     1.9594    0.0000    0.9975      0.0  ...
# 2020-02-11      0.0000     0.0732   -1.8862    0.9975      0.0  ...
# 2020-02-12      0.0000     0.0732    0.0000    0.9975      0.0  ...
# 2020-02-13      0.0000     0.0732    0.0000    0.9975      0.0  ...
#
#               PFE_daily  PFE_diff  PG_daily  PG_diff  TSLA_daily  TSLA_diff  \
# release_date
# 2014-01-04       0.9881    0.0000    0.9866      0.0      0.8641        0.0
# 2014-01-05       0.9881    0.0000    0.9866      0.0      0.8641        0.0
# 2014-01-06       0.9881    0.0000    0.9866      0.0      0.8641        0.0
# 2014-01-07       0.9881    0.0000    0.9866      0.0      0.8641        0.0
# 2014-01-08       0.9881    0.0000    0.9866      0.0      0.8641        0.0
# ...                 ...       ...       ...      ...         ...        ...
# 2020-02-09       1.9891    0.0000   -0.9581      0.0     20.7979        0.0
# 2020-02-10       1.9891    0.0000   -0.9581      0.0     20.7979        0.0
# 2020-02-11       1.5383   -0.4508   -0.9581      0.0     20.7979        0.0
# 2020-02-12       1.5383    0.0000   -0.9581      0.0     20.7979        0.0
# 2020-02-13       0.2732   -1.2651   -0.9581      0.0     20.7979        0.0
#
#               WMT_daily  WMT_diff  XOM_daily  XOM_diff
# release_date
# 2014-01-04       0.9135    0.0000     0.9595    0.0000
# 2014-01-05       0.9135    0.0000     0.9977    0.0382
# 2014-01-06       0.9135    0.0000     0.9967   -0.0010
# 2014-01-07       0.9135    0.0000     0.9967    0.0000
# 2014-01-08       0.9135    0.0000     0.9967    0.0000
# ...                 ...       ...        ...       ...
# 2020-02-09       0.3612   -0.6384    -0.9922    0.0000
# 2020-02-10       0.3612    0.0000    -0.5306    0.4616
# 2020-02-11       0.3612    0.0000     1.9926    2.5232
# 2020-02-12       0.3612    0.0000     1.9926    0.0000
# 2020-02-13       0.3612    0.0000     3.9702    1.9776
#
# [2137 rows x 30 columns]

# %% [markdown]
# # Stock Data

# %%
df_prices = pd.read_csv("../data/stock_data_daily_pct_change.csv")
df_prices.index = pd.DatetimeIndex(df_prices["Date"]).to_period("D")
df_prices = df_prices.drop('Date', axis = 1)
df_prices = df_prices.drop("Date.1", axis = 1)

# Drop columns with little amount of data (determined in "Sentiment Timeseries.ipynb")
df_prices = df_prices.drop(["LLY", "NVDA", "MA", "UNH", "V"], axis = 1)
df_prices
# Out:
#                 AAPL      MSFT       BAC      AMZN      TSLA       XOM  \
# Date
# 2011-01-04  0.005219  0.003931  0.003524  0.004288  0.001878  0.004695
# 2011-01-05  0.008180 -0.003204  0.018258  0.013026  0.005999 -0.002670
# 2011-01-06 -0.000808  0.029286 -0.004138 -0.008324  0.039135  0.006426
# 2011-01-07  0.007161 -0.007634 -0.013158 -0.001991  0.012912  0.005453
# 2011-01-10  0.018833 -0.013287  0.010526 -0.004367  0.007436 -0.006086
# ...              ...       ...       ...       ...       ...       ...
# 2019-12-23  0.016319  0.000000  0.006007  0.003638  0.033605  0.005004
# 2019-12-24  0.000951 -0.000191  0.001422 -0.002114  0.014384 -0.003842
# 2019-12-26  0.019840  0.008197  0.008518  0.044467  0.013380  0.001571
# 2019-12-27 -0.000379  0.001828 -0.004786  0.000551 -0.001300 -0.003422
# 2019-12-30  0.005935 -0.008619 -0.005658 -0.012253 -0.036433 -0.005866
#
#                  JPM        KO       WMT       CVX       JNJ        HD  \
# Date
# 2011-01-04  0.014473 -0.020699  0.003849 -0.003698  0.008437 -0.018125
# 2011-01-05  0.012229 -0.005950 -0.006573 -0.001747 -0.000631 -0.003172
# 2011-01-06 -0.004922 -0.007245 -0.008270 -0.008202 -0.001580 -0.004051
# 2011-01-07 -0.018885 -0.001745  0.002224  0.005514 -0.009650 -0.001162
# 2011-01-10 -0.005500  0.002225 -0.006472 -0.008554 -0.007029  0.000291
# ...              ...       ...       ...       ...       ...       ...
# 2019-12-23 -0.000292 -0.001092 -0.010475  0.005431  0.002602 -0.008952
# 2019-12-24  0.002770 -0.003642  0.004033  0.000083 -0.003483  0.006660
# 2019-12-26  0.010612  0.005666  0.000084  0.002160 -0.000685  0.000680
# 2019-12-27  0.000719  0.005998  0.000586 -0.002487 -0.000548 -0.003849
# 2019-12-30 -0.003666 -0.001445 -0.001589 -0.003741 -0.003088 -0.012093
#
#                   PG       MRK       PFE
# Date
# 2011-01-04  0.002779  0.008602  0.017534
# 2011-01-05 -0.002310  0.005777  0.006671
# 2011-01-06 -0.001698  0.013676  0.003865
# 2011-01-07 -0.002937  0.007825  0.008801
# 2011-01-10 -0.002171 -0.004016 -0.004362
# ...              ...       ...       ...
# 2019-12-23 -0.003670  0.001747  0.002294
# 2019-12-24  0.002562 -0.003270 -0.000763
# 2019-12-26  0.000000 -0.001093  0.002291
# 2019-12-27  0.006948  0.001752 -0.001524
# 2019-12-30 -0.012848 -0.005137 -0.010427
#
# [2262 rows x 15 columns]

# %% [markdown]
# # VAR model of sentiment and prices

# %%
def var_model(df_sentiment: pd.DataFrame, df_prices: pd.DataFrame)-> tuple[VAR, pd.DataFrame]:
    """
    Make a VAR model for a specific stock

    Returns a tuple of the VAR model and a merged dataframe consisting of the prices and
    the sentiment.
    """
    merged_df = pd.merge(df_prices, df_sentiment, left_index= True, right_index = True)
    new_names = {df_sentiment.name: f"{df_prices.name}_sentiment", df_prices.name: f"{df_prices.name}_prices"}
    merged_df = merged_df.rename(new_names, axis=1)
    return VAR(merged_df), merged_df

# %%
# Make a VAR model of all stocks

var_models = []
merged_dfs = []
for ticker in df_prices.columns:
    var, merged_df = var_model(df_sentiment[f"{ticker}_diff"], df_prices[ticker])
    var_models.append(var)
    merged_dfs.append(merged_df)

# %%
results = []
for model in var_models:
    result = model.fit(maxlags=35, ic='aic')
    results.append(result)
    print(result.summary())
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Sun, 25, Dec, 2022
# Time:                     00:04:35
# --------------------------------------------------------------------
# No. of Equations:         2.00000    BIC:                   -3.27623
# Nobs:                     1492.00    HQIC:                  -3.39675
# Log likelihood:          -1592.73    FPE:                  0.0311691
# AIC:                     -3.46833    Det(Omega_mle):       0.0300709
# --------------------------------------------------------------------
# Results for equation AAPL_prices
# =====================================================================================
#                         coefficient       std. error           t-stat            prob
# -------------------------------------------------------------------------------------
# const                      0.001052         0.000412            2.556           0.011
# L1.AAPL_prices             0.018722         0.026095            0.717           0.473
# L1.AAPL_sentiment         -0.000015         0.000035           -0.432           0.665
# L2.AAPL_prices            -0.037282         0.026103           -1.428           0.153
# L2.AAPL_sentiment          0.000041         0.000037            1.097           0.273
# L3.AAPL_prices            -0.015724         0.026120           -0.602           0.547
# L3.AAPL_sentiment          0.000020         0.000039            0.502           0.615
# L4.AAPL_prices             0.005188         0.026046            0.199           0.842
# L4.AAPL_sentiment          0.000009         0.000040            0.229           0.819
# L5.AAPL_prices            -0.002161         0.026031           -0.083           0.934
# L5.AAPL_sentiment          0.000067         0.000041            1.625           0.104
# L6.AAPL_prices             0.005240         0.026021            0.201           0.840
# L6.AAPL_sentiment          0.000061         0.000041            1.483           0.138
# L7.AAPL_prices             0.087574         0.025906            3.380           0.001
# L7.AAPL_sentiment          0.000031         0.000041            0.758           0.449
# L8.AAPL_prices            -0.045145         0.025985           -1.737           0.082
# L8.AAPL_sentiment          0.000019         0.000041            0.455           0.649
# L9.AAPL_prices             0.032378         0.026056            1.243           0.214
# L9.AAPL_sentiment         -0.000045         0.000041           -1.095           0.274
# L10.AAPL_prices           -0.008651         0.026066           -0.332           0.740
# L10.AAPL_sentiment         0.000058         0.000040            1.439           0.150
# L11.AAPL_prices           -0.009538         0.026077           -0.366           0.715
# L11.AAPL_sentiment        -0.000040         0.000040           -1.005           0.315
# L12.AAPL_prices            0.002599         0.026056            0.100           0.921
# L12.AAPL_sentiment        -0.000021         0.000037           -0.550           0.582
# L13.AAPL_prices           -0.014252         0.026063           -0.547           0.585
# L13.AAPL_sentiment        -0.000093         0.000035           -2.633           0.008
# =====================================================================================
#
# Results for equation AAPL_sentiment
# =====================================================================================
#                         coefficient       std. error           t-stat            prob
# -------------------------------------------------------------------------------------
# const                     -0.630234         0.305799           -2.061           0.039
# L1.AAPL_prices            17.734849        19.392005            0.915           0.360
# L1.AAPL_sentiment         -0.380666         0.026066          -14.604           0.000
# L2.AAPL_prices             0.131673        19.398199            0.007           0.995
# L2.AAPL_sentiment         -0.357559         0.027793          -12.865           0.000
# L3.AAPL_prices             6.943587        19.410330            0.358           0.721
# L3.AAPL_sentiment         -0.260752         0.029330           -8.890           0.000
# L4.AAPL_prices            -0.861719        19.355697           -0.045           0.964
# L4.AAPL_sentiment         -0.290022         0.029931           -9.690           0.000
# L5.AAPL_prices           -35.391566        19.344153           -1.830           0.067
# L5.AAPL_sentiment         -0.153186         0.030707           -4.989           0.000
# L6.AAPL_prices            16.625623        19.337068            0.860           0.390
# L6.AAPL_sentiment         -0.143764         0.030675           -4.687           0.000
# L7.AAPL_prices             7.884828        19.251780            0.410           0.682
# L7.AAPL_sentiment         -0.149031         0.030747           -4.847           0.000
# L8.AAPL_prices           -49.274094        19.310583           -2.552           0.011
# L8.AAPL_sentiment         -0.164656         0.030769           -5.351           0.000
# L9.AAPL_prices            11.713333        19.362721            0.605           0.545
# L9.AAPL_sentiment         -0.122097         0.030780           -3.967           0.000
# L10.AAPL_prices           24.797510        19.370525            1.280           0.200
# L10.AAPL_sentiment        -0.116415         0.029976           -3.884           0.000
# L11.AAPL_prices            6.401160        19.378891            0.330           0.741
# L11.AAPL_sentiment        -0.037213         0.029419           -1.265           0.206
# L12.AAPL_prices           19.954720        19.363288            1.031           0.303
# L12.AAPL_sentiment        -0.084673         0.027829           -3.043           0.002
# L13.AAPL_prices           22.586991        19.367882            1.166           0.244
# L13.AAPL_sentiment        -0.081920         0.026131           -3.135           0.002
# =====================================================================================
#
# Correlation matrix of residuals
#                   AAPL_prices  AAPL_sentiment
# AAPL_prices          1.000000        0.046622
# AAPL_sentiment       0.046622        1.000000
#
#
#
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Sun, 25, Dec, 2022
# Time:                     00:04:35
# --------------------------------------------------------------------
# No. of Equations:         2.00000    BIC:                   -4.31858
# Nobs:                     1489.00    HQIC:                  -4.46612
# Log likelihood:          -769.322    FPE:                  0.0105277
# AIC:                     -4.55376    Det(Omega_mle):       0.0100761
# --------------------------------------------------------------------
# Results for equation MSFT_prices
# =====================================================================================
#                         coefficient       std. error           t-stat            prob
# -------------------------------------------------------------------------------------
# const                      0.001660         0.000398            4.173           0.000
# L1.MSFT_prices            -0.066767         0.026213           -2.547           0.011
# L1.MSFT_sentiment          0.000104         0.000052            2.006           0.045
# L2.MSFT_prices            -0.068259         0.026209           -2.604           0.009
# L2.MSFT_sentiment          0.000034         0.000057            0.603           0.546
# L3.MSFT_prices             0.004640         0.026216            0.177           0.859
# L3.MSFT_sentiment          0.000082         0.000062            1.333           0.183
# L4.MSFT_prices            -0.056300         0.026199           -2.149           0.032
# L4.MSFT_sentiment          0.000063         0.000064            0.982           0.326
# L5.MSFT_prices            -0.065650         0.026237           -2.502           0.012
# L5.MSFT_sentiment         -0.000007         0.000064           -0.108           0.914
# L6.MSFT_prices            -0.035197         0.026302           -1.338           0.181
# L6.MSFT_sentiment          0.000000         0.000065            0.006           0.995
# L7.MSFT_prices             0.005314         0.026326            0.202           0.840
# L7.MSFT_sentiment          0.000048         0.000065            0.734           0.463
# L8.MSFT_prices            -0.084813         0.026327           -3.222           0.001
# L8.MSFT_sentiment          0.000001         0.000066            0.008           0.993
# L9.MSFT_prices            -0.023296         0.026297           -0.886           0.376
# L9.MSFT_sentiment          0.000024         0.000066            0.362           0.718
# L10.MSFT_prices            0.005092         0.026287            0.194           0.846
# L10.MSFT_sentiment        -0.000012         0.000066           -0.185           0.854
# L11.MSFT_prices            0.004049         0.026239            0.154           0.877
# L11.MSFT_sentiment        -0.000018         0.000066           -0.270           0.787
# L12.MSFT_prices           -0.021377         0.026186           -0.816           0.414
# L12.MSFT_sentiment        -0.000066         0.000065           -1.013           0.311
# L13.MSFT_prices           -0.001821         0.026130           -0.070           0.944
# L13.MSFT_sentiment        -0.000019         0.000065           -0.291           0.771
# L14.MSFT_prices            0.003713         0.026103            0.142           0.887
# L14.MSFT_sentiment        -0.000163         0.000063           -2.605           0.009
# L15.MSFT_prices           -0.024365         0.026050           -0.935           0.350
# L15.MSFT_sentiment        -0.000109         0.000058           -1.886           0.059
# L16.MSFT_prices            0.006629         0.025956            0.255           0.798
# L16.MSFT_sentiment        -0.000006         0.000053           -0.103           0.918
# =====================================================================================
#
# Results for equation MSFT_sentiment
# =====================================================================================
#                         coefficient       std. error           t-stat            prob
# -------------------------------------------------------------------------------------
# const                      0.071230         0.199870            0.356           0.722
# L1.MSFT_prices             2.823645        13.168116            0.214           0.830
# L1.MSFT_sentiment         -0.452605         0.026025          -17.391           0.000
# L2.MSFT_prices            -4.296171        13.165753           -0.326           0.744
# L2.MSFT_sentiment         -0.497140         0.028412          -17.498           0.000
# L3.MSFT_prices             0.587190        13.169259            0.045           0.964
# L3.MSFT_sentiment         -0.308739         0.031000           -9.959           0.000
# L4.MSFT_prices             9.283074        13.160812            0.705           0.481
# L4.MSFT_sentiment         -0.163555         0.032037           -5.105           0.000
# L5.MSFT_prices           -10.723549        13.179902           -0.814           0.416
# L5.MSFT_sentiment         -0.190808         0.032327           -5.902           0.000
# L6.MSFT_prices           -18.687821        13.212860           -1.414           0.157
# L6.MSFT_sentiment         -0.159331         0.032584           -4.890           0.000
# L7.MSFT_prices           -12.062429        13.224777           -0.912           0.362
# L7.MSFT_sentiment         -0.128133         0.032897           -3.895           0.000
# L8.MSFT_prices             7.986734        13.225071            0.604           0.546
# L8.MSFT_sentiment         -0.104310         0.033309           -3.132           0.002
# L9.MSFT_prices             0.666365        13.210233            0.050           0.960
# L9.MSFT_sentiment         -0.021193         0.033330           -0.636           0.525
# L10.MSFT_prices           -2.496132        13.205179           -0.189           0.850
# L10.MSFT_sentiment         0.073971         0.033208            2.228           0.026
# L11.MSFT_prices           -8.739514        13.181083           -0.663           0.507
# L11.MSFT_sentiment         0.107060         0.032984            3.246           0.001
# L12.MSFT_prices            1.520852        13.154272            0.116           0.908
# L12.MSFT_sentiment        -0.018701         0.032713           -0.572           0.568
# L13.MSFT_prices           -0.114819        13.126349           -0.009           0.993
# L13.MSFT_sentiment        -0.041254         0.032461           -1.271           0.204
# L14.MSFT_prices          -14.853666        13.112448           -1.133           0.257
# L14.MSFT_sentiment        -0.158348         0.031487           -5.029           0.000
# L15.MSFT_prices            8.870495        13.086080            0.678           0.498
# L15.MSFT_sentiment        -0.134675         0.028959           -4.650           0.000
# L16.MSFT_prices           -1.202179        13.038865           -0.092           0.927
# L16.MSFT_sentiment        -0.121413         0.026795           -4.531           0.000
# =====================================================================================
#
# Correlation matrix of residuals
#                   MSFT_prices  MSFT_sentiment
# MSFT_prices          1.000000       -0.007887
# MSFT_sentiment      -0.007887        1.000000
#
#
#
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Sun, 25, Dec, 2022
# Time:                     00:04:36
# --------------------------------------------------------------------
# No. of Equations:         2.00000    BIC:                   -6.70972
# Nobs:                     1499.00    HQIC:                  -6.76754
# Log likelihood:           870.021    FPE:                 0.00111170
# AIC:                     -6.80187    Det(Omega_mle):      0.00109267
# --------------------------------------------------------------------
# Results for equation BAC_prices
# ===================================================================================
#                       coefficient       std. error           t-stat            prob
# -----------------------------------------------------------------------------------
# const                    0.000566         0.000411            1.379           0.168
# L1.BAC_prices            0.029172         0.025930            1.125           0.261
# L1.BAC_sentiment         0.000258         0.000194            1.328           0.184
# L2.BAC_prices           -0.016593         0.025916           -0.640           0.522
# L2.BAC_sentiment         0.000083         0.000208            0.400           0.689
# L3.BAC_prices            0.035030         0.025896            1.353           0.176
# L3.BAC_sentiment         0.000363         0.000213            1.706           0.088
# L4.BAC_prices           -0.034062         0.025885           -1.316           0.188
# L4.BAC_sentiment         0.000485         0.000213            2.276           0.023
# L5.BAC_prices           -0.027364         0.025898           -1.057           0.291
# L5.BAC_sentiment         0.000501         0.000209            2.400           0.016
# L6.BAC_prices            0.035211         0.025859            1.362           0.173
# L6.BAC_sentiment         0.000442         0.000194            2.273           0.023
# ===================================================================================
#
# Results for equation BAC_sentiment
# ===================================================================================
#                       coefficient       std. error           t-stat            prob
# -----------------------------------------------------------------------------------
# const                    0.122000         0.054951            2.220           0.026
# L1.BAC_prices           -3.015033         3.468404           -0.869           0.385
# L1.BAC_sentiment        -0.397529         0.025964          -15.311           0.000
# L2.BAC_prices            3.189864         3.466541            0.920           0.357
# L2.BAC_sentiment        -0.250069         0.027886           -8.967           0.000
# L3.BAC_prices            0.216138         3.463789            0.062           0.950
# L3.BAC_sentiment        -0.172514         0.028483           -6.057           0.000
# L4.BAC_prices           -3.441019         3.462310           -0.994           0.320
# L4.BAC_sentiment        -0.106410         0.028489           -3.735           0.000
# L5.BAC_prices           -1.441888         3.464144           -0.416           0.677
# L5.BAC_sentiment        -0.077341         0.027913           -2.771           0.006
# L6.BAC_prices           -3.100279         3.458933           -0.896           0.370
# L6.BAC_sentiment        -0.000103         0.025991           -0.004           0.997
# ===================================================================================
#
# Correlation matrix of residuals
#                  BAC_prices  BAC_sentiment
# BAC_prices         1.000000       0.070940
# BAC_sentiment      0.070940       1.000000
#
#
#
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Sun, 25, Dec, 2022
# Time:                     00:04:37
# --------------------------------------------------------------------
# No. of Equations:         2.00000    BIC:                   -4.60912
# Nobs:                     1496.00    HQIC:                  -4.69375
# Log likelihood:          -658.942    FPE:                 0.00870366
# AIC:                     -4.74401    Det(Omega_mle):      0.00848672
# --------------------------------------------------------------------
# Results for equation AMZN_prices
# ====================================================================================
#                        coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------------
# const                     0.001243         0.000499            2.493           0.013
# L1.AMZN_prices            0.006698         0.026046            0.257           0.797
# L1.AMZN_sentiment         0.000004         0.000100            0.045           0.964
# L2.AMZN_prices           -0.034086         0.026031           -1.309           0.190
# L2.AMZN_sentiment         0.000004         0.000109            0.038           0.970
# L3.AMZN_prices           -0.037113         0.026092           -1.422           0.155
# L3.AMZN_sentiment        -0.000039         0.000112           -0.344           0.731
# L4.AMZN_prices           -0.038640         0.026084           -1.481           0.139
# L4.AMZN_sentiment         0.000078         0.000114            0.686           0.493
# L5.AMZN_prices            0.029078         0.026107            1.114           0.265
# L5.AMZN_sentiment         0.000096         0.000114            0.836           0.403
# L6.AMZN_prices           -0.001456         0.026118           -0.056           0.956
# L6.AMZN_sentiment         0.000244         0.000114            2.145           0.032
# L7.AMZN_prices            0.004988         0.026143            0.191           0.849
# L7.AMZN_sentiment         0.000105         0.000112            0.936           0.349
# L8.AMZN_prices           -0.030829         0.026133           -1.180           0.238
# L8.AMZN_sentiment         0.000141         0.000109            1.298           0.194
# L9.AMZN_prices            0.030090         0.026148            1.151           0.250
# L9.AMZN_sentiment         0.000035         0.000100            0.350           0.726
# ====================================================================================
#
# Results for equation AMZN_sentiment
# ====================================================================================
#                        coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------------
# const                     0.207419         0.129799            1.598           0.110
# L1.AMZN_prices            6.530386         6.777403            0.964           0.335
# L1.AMZN_sentiment        -0.440923         0.025978          -16.973           0.000
# L2.AMZN_prices           -6.972778         6.773622           -1.029           0.303
# L2.AMZN_sentiment        -0.283908         0.028398           -9.997           0.000
# L3.AMZN_prices           -7.536443         6.789336           -1.110           0.267
# L3.AMZN_sentiment        -0.193960         0.029230           -6.636           0.000
# L4.AMZN_prices           -9.925675         6.787301           -1.462           0.144
# L4.AMZN_sentiment        -0.107876         0.029623           -3.642           0.000
# L5.AMZN_prices           11.611498         6.793340            1.709           0.087
# L5.AMZN_sentiment        -0.026080         0.029752           -0.877           0.381
# L6.AMZN_prices          -15.494476         6.796326           -2.280           0.023
# L6.AMZN_sentiment         0.039530         0.029623            1.334           0.182
# L7.AMZN_prices            8.190456         6.802750            1.204           0.229
# L7.AMZN_sentiment         0.098545         0.029216            3.373           0.001
# L8.AMZN_prices           -5.966000         6.800244           -0.877           0.380
# L8.AMZN_sentiment         0.030171         0.028356            1.064           0.287
# L9.AMZN_prices           -2.560654         6.803910           -0.376           0.707
# L9.AMZN_sentiment        -0.080800         0.025914           -3.118           0.002
# ====================================================================================
#
# Correlation matrix of residuals
#                   AMZN_prices  AMZN_sentiment
# AMZN_prices          1.000000        0.053755
# AMZN_sentiment       0.053755        1.000000
#
#
#
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Sun, 25, Dec, 2022
# Time:                     00:04:38
# --------------------------------------------------------------------
# No. of Equations:         2.00000    BIC:                   -5.88500
# Nobs:                     1501.00    HQIC:                  -5.92499
# Log likelihood:           222.865    FPE:                 0.00260916
# AIC:                     -5.94873    Det(Omega_mle):      0.00257815
# --------------------------------------------------------------------
# Results for equation TSLA_prices
# ====================================================================================
#                        coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------------
# const                     0.001272         0.000749            1.700           0.089
# L1.TSLA_prices           -0.000640         0.025900           -0.025           0.980
# L1.TSLA_sentiment        -0.000476         0.000421           -1.131           0.258
# L2.TSLA_prices            0.030380         0.025910            1.173           0.241
# L2.TSLA_sentiment        -0.000763         0.000438           -1.741           0.082
# L3.TSLA_prices           -0.008561         0.025911           -0.330           0.741
# L3.TSLA_sentiment        -0.000247         0.000440           -0.560           0.576
# L4.TSLA_prices           -0.025959         0.025951           -1.000           0.317
# L4.TSLA_sentiment        -0.000278         0.000422           -0.657           0.511
# ====================================================================================
#
# Results for equation TSLA_sentiment
# ====================================================================================
#                        coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------------
# const                     0.138391         0.046065            3.004           0.003
# L1.TSLA_prices            1.885152         1.593793            1.183           0.237
# L1.TSLA_sentiment        -0.316387         0.025889          -12.221           0.000
# L2.TSLA_prices            1.587589         1.594405            0.996           0.319
# L2.TSLA_sentiment        -0.332926         0.026971          -12.344           0.000
# L3.TSLA_prices           -3.433481         1.594498           -2.153           0.031
# L3.TSLA_sentiment        -0.110250         0.027105           -4.068           0.000
# L4.TSLA_prices            0.966736         1.596917            0.605           0.545
# L4.TSLA_sentiment        -0.080808         0.025985           -3.110           0.002
# ====================================================================================
#
# Correlation matrix of residuals
#                   TSLA_prices  TSLA_sentiment
# TSLA_prices          1.000000        0.035315
# TSLA_sentiment       0.035315        1.000000
#
#
#
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Sun, 25, Dec, 2022
# Time:                     00:04:38
# --------------------------------------------------------------------
# No. of Equations:         2.00000    BIC:                   -8.13019
# Nobs:                     1500.00    HQIC:                  -8.17909
# Log likelihood:           1921.27    FPE:                0.000272433
# AIC:                     -8.20812    Det(Omega_mle):     0.000268481
# --------------------------------------------------------------------
# Results for equation XOM_prices
# ===================================================================================
#                       coefficient       std. error           t-stat            prob
# -----------------------------------------------------------------------------------
# const                   -0.000001         0.000304           -0.003           0.998
# L1.XOM_prices            0.000630         0.025924            0.024           0.981
# L1.XOM_sentiment        -0.000459         0.000217           -2.111           0.035
# L2.XOM_prices            0.005135         0.025873            0.198           0.843
# L2.XOM_sentiment        -0.000407         0.000236           -1.726           0.084
# L3.XOM_prices           -0.016392         0.025882           -0.633           0.527
# L3.XOM_sentiment         0.000009         0.000243            0.037           0.970
# L4.XOM_prices           -0.063061         0.025856           -2.439           0.015
# L4.XOM_sentiment         0.000008         0.000236            0.032           0.975
# L5.XOM_prices           -0.029409         0.025908           -1.135           0.256
# L5.XOM_sentiment        -0.000091         0.000218           -0.419           0.675
# ===================================================================================
#
# Results for equation XOM_sentiment
# ===================================================================================
#                       coefficient       std. error           t-stat            prob
# -----------------------------------------------------------------------------------
# const                    0.071579         0.036205            1.977           0.048
# L1.XOM_prices            2.141038         3.085738            0.694           0.488
# L1.XOM_sentiment        -0.438417         0.025860          -16.953           0.000
# L2.XOM_prices            3.830830         3.079636            1.244           0.214
# L2.XOM_sentiment        -0.297607         0.028070          -10.602           0.000
# L3.XOM_prices           -0.029359         3.080800           -0.010           0.992
# L3.XOM_sentiment        -0.134208         0.028919           -4.641           0.000
# L4.XOM_prices            0.918843         3.077688            0.299           0.765
# L4.XOM_sentiment        -0.125333         0.028140           -4.454           0.000
# L5.XOM_prices           -4.630362         3.083903           -1.501           0.133
# L5.XOM_sentiment        -0.072113         0.025947           -2.779           0.005
# ===================================================================================
#
# Correlation matrix of residuals
#                  XOM_prices  XOM_sentiment
# XOM_prices         1.000000       0.040882
# XOM_sentiment      0.040882       1.000000
#
#
#
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Sun, 25, Dec, 2022
# Time:                     00:04:39
# --------------------------------------------------------------------
# No. of Equations:         2.00000    BIC:                   -8.14848
# Nobs:                     1501.00    HQIC:                  -8.18847
# Log likelihood:           1921.61    FPE:                0.000271321
# AIC:                     -8.21221    Det(Omega_mle):     0.000268097
# --------------------------------------------------------------------
# Results for equation JPM_prices
# ===================================================================================
#                       coefficient       std. error           t-stat            prob
# -----------------------------------------------------------------------------------
# const                    0.000797         0.000336            2.368           0.018
# L1.JPM_prices            0.006008         0.025847            0.232           0.816
# L1.JPM_sentiment        -0.000421         0.000264           -1.593           0.111
# L2.JPM_prices           -0.014518         0.025838           -0.562           0.574
# L2.JPM_sentiment        -0.000220         0.000287           -0.767           0.443
# L3.JPM_prices            0.020450         0.025893            0.790           0.430
# L3.JPM_sentiment        -0.000113         0.000287           -0.395           0.693
# L4.JPM_prices           -0.053133         0.025878           -2.053           0.040
# L4.JPM_sentiment        -0.000219         0.000264           -0.827           0.408
# ===================================================================================
#
# Results for equation JPM_sentiment
# ===================================================================================
#                       coefficient       std. error           t-stat            prob
# -----------------------------------------------------------------------------------
# const                    0.026249         0.032891            0.798           0.425
# L1.JPM_prices            0.847404         2.526794            0.335           0.737
# L1.JPM_sentiment        -0.454266         0.025853          -17.571           0.000
# L2.JPM_prices           -6.682152         2.525968           -2.645           0.008
# L2.JPM_sentiment        -0.250738         0.028056           -8.937           0.000
# L3.JPM_prices            0.588306         2.531258            0.232           0.816
# L3.JPM_sentiment        -0.173694         0.028017           -6.200           0.000
# L4.JPM_prices            0.067916         2.529855            0.027           0.979
# L4.JPM_sentiment        -0.052974         0.025852           -2.049           0.040
# ===================================================================================
#
# Correlation matrix of residuals
#                  JPM_prices  JPM_sentiment
# JPM_prices         1.000000       0.003783
# JPM_sentiment      0.003783       1.000000
#
#
#
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Sun, 25, Dec, 2022
# Time:                     00:04:40
# --------------------------------------------------------------------
# No. of Equations:         2.00000    BIC:                   -9.50892
# Nobs:                     1497.00    HQIC:                  -9.58461
# Log likelihood:           2993.42    FPE:                6.57567e-05
# AIC:                     -9.62955    Det(Omega_mle):     6.42883e-05
# --------------------------------------------------------------------
# Results for equation KO_prices
# ==================================================================================
#                      coefficient       std. error           t-stat            prob
# ----------------------------------------------------------------------------------
# const                   0.000430         0.000234            1.838           0.066
# L1.KO_prices            0.010595         0.025988            0.408           0.683
# L1.KO_sentiment         0.000358         0.000261            1.371           0.170
# L2.KO_prices           -0.080733         0.025986           -3.107           0.002
# L2.KO_sentiment        -0.000049         0.000274           -0.180           0.857
# L3.KO_prices            0.008835         0.026005            0.340           0.734
# L3.KO_sentiment         0.000035         0.000277            0.128           0.898
# L4.KO_prices           -0.022382         0.025971           -0.862           0.389
# L4.KO_sentiment        -0.000043         0.000280           -0.153           0.878
# L5.KO_prices            0.035829         0.025977            1.379           0.168
# L5.KO_sentiment         0.000462         0.000280            1.653           0.098
# L6.KO_prices           -0.041130         0.025992           -1.582           0.114
# L6.KO_sentiment         0.000227         0.000277            0.820           0.412
# L7.KO_prices           -0.009403         0.025936           -0.363           0.717
# L7.KO_sentiment        -0.000494         0.000274           -1.800           0.072
# L8.KO_prices           -0.016586         0.025927           -0.640           0.522
# L8.KO_sentiment         0.000189         0.000263            0.718           0.473
# ==================================================================================
#
# Results for equation KO_sentiment
# ==================================================================================
#                      coefficient       std. error           t-stat            prob
# ----------------------------------------------------------------------------------
# const                   0.001393         0.023266            0.060           0.952
# L1.KO_prices            5.091894         2.585531            1.969           0.049
# L1.KO_sentiment        -0.324442         0.025938          -12.508           0.000
# L2.KO_prices           -0.721771         2.585379           -0.279           0.780
# L2.KO_sentiment        -0.193887         0.027230           -7.120           0.000
# L3.KO_prices            3.120153         2.587274            1.206           0.228
# L3.KO_sentiment        -0.205311         0.027518           -7.461           0.000
# L4.KO_prices            2.776571         2.583868            1.075           0.283
# L4.KO_sentiment        -0.126068         0.027851           -4.527           0.000
# L5.KO_prices           -0.726308         2.584415           -0.281           0.779
# L5.KO_sentiment        -0.118482         0.027831           -4.257           0.000
# L6.KO_prices           -0.624096         2.585907           -0.241           0.809
# L6.KO_sentiment        -0.121615         0.027558           -4.413           0.000
# L7.KO_prices            0.311939         2.580405            0.121           0.904
# L7.KO_sentiment        -0.081833         0.027282           -3.000           0.003
# L8.KO_prices           -3.922836         2.579468           -1.521           0.128
# L8.KO_sentiment        -0.065418         0.026140           -2.503           0.012
# ==================================================================================
#
# Correlation matrix of residuals
#                 KO_prices  KO_sentiment
# KO_prices        1.000000     -0.011535
# KO_sentiment    -0.011535      1.000000
#
#
#
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Sun, 25, Dec, 2022
# Time:                     00:04:41
# --------------------------------------------------------------------
# No. of Equations:         2.00000    BIC:                   -9.06924
# Nobs:                     1500.00    HQIC:                  -9.11814
# Log likelihood:           2625.56    FPE:                0.000106521
# AIC:                     -9.14717    Det(Omega_mle):     0.000104975
# --------------------------------------------------------------------
# Results for equation WMT_prices
# ===================================================================================
#                       coefficient       std. error           t-stat            prob
# -----------------------------------------------------------------------------------
# const                    0.000465         0.000306            1.518           0.129
# L1.WMT_prices           -0.050080         0.025994           -1.927           0.054
# L1.WMT_sentiment         0.000312         0.000349            0.895           0.371
# L2.WMT_prices           -0.035614         0.025984           -1.371           0.170
# L2.WMT_sentiment        -0.000126         0.000359           -0.350           0.726
# L3.WMT_prices           -0.010221         0.025993           -0.393           0.694
# L3.WMT_sentiment         0.000426         0.000367            1.162           0.245
# L4.WMT_prices           -0.033928         0.025982           -1.306           0.192
# L4.WMT_sentiment         0.000716         0.000360            1.990           0.047
# L5.WMT_prices           -0.012282         0.025960           -0.473           0.636
# L5.WMT_sentiment         0.000567         0.000350            1.618           0.106
# ===================================================================================
#
# Results for equation WMT_sentiment
# ===================================================================================
#                       coefficient       std. error           t-stat            prob
# -----------------------------------------------------------------------------------
# const                    0.041793         0.022705            1.841           0.066
# L1.WMT_prices           -0.218161         1.927120           -0.113           0.910
# L1.WMT_sentiment        -0.245948         0.025897           -9.497           0.000
# L2.WMT_prices           -1.394080         1.926335           -0.724           0.469
# L2.WMT_sentiment        -0.219950         0.026644           -8.255           0.000
# L3.WMT_prices           -0.583314         1.927052           -0.303           0.762
# L3.WMT_sentiment        -0.087319         0.027193           -3.211           0.001
# L4.WMT_prices            1.291216         1.926166            0.670           0.503
# L4.WMT_sentiment        -0.063115         0.026681           -2.366           0.018
# L5.WMT_prices            0.242057         1.924535            0.126           0.900
# L5.WMT_sentiment        -0.097865         0.025955           -3.771           0.000
# ===================================================================================
#
# Correlation matrix of residuals
#                  WMT_prices  WMT_sentiment
# WMT_prices         1.000000       0.093393
# WMT_sentiment      0.093393       1.000000
#
#
#
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Sun, 25, Dec, 2022
# Time:                     00:04:41
# --------------------------------------------------------------------
# No. of Equations:         2.00000    BIC:                   -8.98296
# Nobs:                     1495.00    HQIC:                  -9.07655
# Log likelihood:           2625.64    FPE:                0.000108135
# AIC:                     -9.13213    Det(Omega_mle):     0.000105160
# --------------------------------------------------------------------
# Results for equation CVX_prices
# ====================================================================================
#                        coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------------
# const                     0.000203         0.000352            0.577           0.564
# L1.CVX_prices             0.011064         0.026043            0.425           0.671
# L1.CVX_sentiment          0.000021         0.000463            0.046           0.964
# L2.CVX_prices            -0.016914         0.026043           -0.649           0.516
# L2.CVX_sentiment         -0.000379         0.000494           -0.767           0.443
# L3.CVX_prices            -0.022235         0.026010           -0.855           0.393
# L3.CVX_sentiment         -0.000777         0.000499           -1.557           0.120
# L4.CVX_prices            -0.018355         0.026014           -0.706           0.480
# L4.CVX_sentiment         -0.001175         0.000503           -2.334           0.020
# L5.CVX_prices            -0.072553         0.025992           -2.791           0.005
# L5.CVX_sentiment         -0.001001         0.000504           -1.985           0.047
# L6.CVX_prices             0.035601         0.025972            1.371           0.170
# L6.CVX_sentiment         -0.000363         0.000505           -0.718           0.473
# L7.CVX_prices             0.015141         0.025970            0.583           0.560
# L7.CVX_sentiment         -0.000461         0.000505           -0.914           0.361
# L8.CVX_prices            -0.032815         0.025959           -1.264           0.206
# L8.CVX_sentiment         -0.001351         0.000502           -2.694           0.007
# L9.CVX_prices             0.005439         0.025985            0.209           0.834
# L9.CVX_sentiment         -0.000662         0.000497           -1.330           0.184
# L10.CVX_prices           -0.010270         0.025976           -0.395           0.693
# L10.CVX_sentiment        -0.000438         0.000465           -0.942           0.346
# ====================================================================================
#
# Results for equation CVX_sentiment
# ====================================================================================
#                        coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------------
# const                    -0.032949         0.019750           -1.668           0.095
# L1.CVX_prices             1.365026         1.462733            0.933           0.351
# L1.CVX_sentiment         -0.384868         0.025980          -14.814           0.000
# L2.CVX_prices             2.463871         1.462761            1.684           0.092
# L2.CVX_sentiment         -0.193838         0.027740           -6.988           0.000
# L3.CVX_prices             0.382047         1.460891            0.262           0.794
# L3.CVX_sentiment         -0.185618         0.028048           -6.618           0.000
# L4.CVX_prices             0.094659         1.461099            0.065           0.948
# L4.CVX_sentiment         -0.118609         0.028279           -4.194           0.000
# L5.CVX_prices            -0.281460         1.459899           -0.193           0.847
# L5.CVX_sentiment         -0.169443         0.028321           -5.983           0.000
# L6.CVX_prices            -0.577747         1.458751           -0.396           0.692
# L6.CVX_sentiment         -0.121146         0.028366           -4.271           0.000
# L7.CVX_prices             0.910793         1.458666            0.624           0.532
# L7.CVX_sentiment         -0.135409         0.028369           -4.773           0.000
# L8.CVX_prices             2.240868         1.458027            1.537           0.124
# L8.CVX_sentiment         -0.107842         0.028175           -3.828           0.000
# L9.CVX_prices             0.110641         1.459509            0.076           0.940
# L9.CVX_sentiment         -0.095432         0.027936           -3.416           0.001
# L10.CVX_prices            3.428540         1.458958            2.350           0.019
# L10.CVX_sentiment        -0.044322         0.026136           -1.696           0.090
# ====================================================================================
#
# Correlation matrix of residuals
#                  CVX_prices  CVX_sentiment
# CVX_prices         1.000000       0.019140
# CVX_sentiment      0.019140       1.000000
#
#
#
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Sun, 25, Dec, 2022
# Time:                     00:04:42
# --------------------------------------------------------------------
# No. of Equations:         2.00000    BIC:                   -9.81250
# Nobs:                     1498.00    HQIC:                  -9.87925
# Log likelihood:           3208.10    FPE:                4.92364e-05
# AIC:                     -9.91888    Det(Omega_mle):     4.82650e-05
# --------------------------------------------------------------------
# Results for equation JNJ_prices
# ===================================================================================
#                       coefficient       std. error           t-stat            prob
# -----------------------------------------------------------------------------------
# const                    0.000463         0.000262            1.769           0.077
# L1.JNJ_prices           -0.031188         0.025975           -1.201           0.230
# L1.JNJ_sentiment         0.000493         0.000377            1.305           0.192
# L2.JNJ_prices           -0.045429         0.026037           -1.745           0.081
# L2.JNJ_sentiment         0.000313         0.000386            0.811           0.417
# L3.JNJ_prices            0.051963         0.026076            1.993           0.046
# L3.JNJ_sentiment         0.000079         0.000391            0.202           0.840
# L4.JNJ_prices           -0.063913         0.026091           -2.450           0.014
# L4.JNJ_sentiment        -0.000441         0.000391           -1.127           0.260
# L5.JNJ_prices            0.046849         0.026124            1.793           0.073
# L5.JNJ_sentiment        -0.000002         0.000391           -0.004           0.997
# L6.JNJ_prices           -0.016088         0.026092           -0.617           0.537
# L6.JNJ_sentiment        -0.000086         0.000385           -0.223           0.824
# L7.JNJ_prices           -0.016418         0.026096           -0.629           0.529
# L7.JNJ_sentiment         0.000183         0.000376            0.486           0.627
# ===================================================================================
#
# Results for equation JNJ_sentiment
# ===================================================================================
#                       coefficient       std. error           t-stat            prob
# -----------------------------------------------------------------------------------
# const                   -0.007060         0.017975           -0.393           0.695
# L1.JNJ_prices            4.419846         1.782377            2.480           0.013
# L1.JNJ_sentiment        -0.232518         0.025903           -8.977           0.000
# L2.JNJ_prices           -3.701727         1.786601           -2.072           0.038
# L2.JNJ_sentiment        -0.206359         0.026513           -7.783           0.000
# L3.JNJ_prices           -3.804694         1.789316           -2.126           0.033
# L3.JNJ_sentiment        -0.122000         0.026821           -4.549           0.000
# L4.JNJ_prices            1.962052         1.790289            1.096           0.273
# L4.JNJ_sentiment        -0.116394         0.026820           -4.340           0.000
# L5.JNJ_prices           -1.430417         1.792603           -0.798           0.425
# L5.JNJ_sentiment        -0.135974         0.026801           -5.073           0.000
# L6.JNJ_prices            1.302609         1.790391            0.728           0.467
# L6.JNJ_sentiment        -0.082590         0.026436           -3.124           0.002
# L7.JNJ_prices            0.230094         1.790640            0.128           0.898
# ...
# L3.HD_prices            2.049109         1.665738            1.230           0.219
# L3.HD_sentiment        -0.155765         0.027924           -5.578           0.000
# L4.HD_prices            2.295190         1.663658            1.380           0.168
# L4.HD_sentiment        -0.071338         0.027293           -2.614           0.009
# L5.HD_prices            0.596631         1.663332            0.359           0.720
# L5.HD_sentiment        -0.098415         0.025866           -3.805           0.000
# ==================================================================================
#
# Correlation matrix of residuals
#                 HD_prices  HD_sentiment
# HD_prices        1.000000      0.078843
# HD_sentiment     0.078843      1.000000
#
#
#
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Sun, 25, Dec, 2022
# Time:                     00:04:43
# --------------------------------------------------------------------
# No. of Equations:         2.00000    BIC:                   -10.3841
# Nobs:                     1497.00    HQIC:                  -10.4598
# Log likelihood:           3648.47    FPE:                2.74073e-05
# AIC:                     -10.5047    Det(Omega_mle):     2.67952e-05
# --------------------------------------------------------------------
# Results for equation PG_prices
# ==================================================================================
#                      coefficient       std. error           t-stat            prob
# ----------------------------------------------------------------------------------
# const                   0.000515         0.000248            2.076           0.038
# L1.PG_prices           -0.039298         0.026024           -1.510           0.131
# L1.PG_sentiment         0.000847         0.000453            1.870           0.061
# L2.PG_prices           -0.031897         0.026020           -1.226           0.220
# L2.PG_sentiment         0.000457         0.000463            0.986           0.324
# L3.PG_prices           -0.007374         0.026046           -0.283           0.777
# L3.PG_sentiment         0.000140         0.000472            0.296           0.767
# L4.PG_prices           -0.059473         0.026035           -2.284           0.022
# L4.PG_sentiment        -0.000463         0.000472           -0.981           0.326
# L5.PG_prices            0.024941         0.026026            0.958           0.338
# L5.PG_sentiment         0.000224         0.000472            0.474           0.636
# L6.PG_prices            0.001347         0.026016            0.052           0.959
# L6.PG_sentiment         0.000548         0.000472            1.160           0.246
# L7.PG_prices           -0.007395         0.025987           -0.285           0.776
# L7.PG_sentiment         0.000608         0.000463            1.312           0.190
# L8.PG_prices           -0.000469         0.025940           -0.018           0.986
# L8.PG_sentiment        -0.000379         0.000454           -0.834           0.404
# ==================================================================================
#
# Results for equation PG_sentiment
# ==================================================================================
#                      coefficient       std. error           t-stat            prob
# ----------------------------------------------------------------------------------
# const                  -0.000509         0.014264           -0.036           0.972
# L1.PG_prices            1.194463         1.496220            0.798           0.425
# L1.PG_sentiment        -0.227627         0.026043           -8.741           0.000
# L2.PG_prices            2.707531         1.495997            1.810           0.070
# L2.PG_sentiment        -0.217090         0.026628           -8.153           0.000
# L3.PG_prices            0.685080         1.497510            0.457           0.647
# L3.PG_sentiment        -0.197426         0.027143           -7.274           0.000
# L4.PG_prices           -0.638096         1.496882           -0.426           0.670
# L4.PG_sentiment        -0.118693         0.027119           -4.377           0.000
# L5.PG_prices            1.751449         1.496354            1.170           0.242
# L5.PG_sentiment        -0.199405         0.027120           -7.353           0.000
# L6.PG_prices            0.793688         1.495787            0.531           0.596
# L6.PG_sentiment        -0.084437         0.027150           -3.110           0.002
# L7.PG_prices           -0.220176         1.494110           -0.147           0.883
# L7.PG_sentiment        -0.097879         0.026647           -3.673           0.000
# L8.PG_prices           -1.390476         1.491413           -0.932           0.351
# L8.PG_sentiment        -0.076242         0.026103           -2.921           0.003
# ==================================================================================
#
# Correlation matrix of residuals
#                 PG_prices  PG_sentiment
# PG_prices        1.000000      0.032332
# PG_sentiment     0.032332      1.000000
#
#
#
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Sun, 25, Dec, 2022
# Time:                     00:04:43
# --------------------------------------------------------------------
# No. of Equations:         2.00000    BIC:                   -9.83578
# Nobs:                     1499.00    HQIC:                  -9.89360
# Log likelihood:           3213.01    FPE:                4.87928e-05
# AIC:                     -9.92793    Det(Omega_mle):     4.79573e-05
# --------------------------------------------------------------------
# Results for equation MRK_prices
# ===================================================================================
#                       coefficient       std. error           t-stat            prob
# -----------------------------------------------------------------------------------
# const                    0.000666         0.000316            2.104           0.035
# L1.MRK_prices            0.000655         0.025660            0.026           0.980
# L1.MRK_sentiment         0.000183         0.000549            0.333           0.739
# L2.MRK_prices           -0.064269         0.025631           -2.507           0.012
# L2.MRK_sentiment        -0.000131         0.000562           -0.234           0.815
# L3.MRK_prices           -0.002121         0.025669           -0.083           0.934
# L3.MRK_sentiment         0.000107         0.000566            0.190           0.850
# L4.MRK_prices           -0.033819         0.025679           -1.317           0.188
# L4.MRK_sentiment         0.000153         0.000567            0.270           0.787
# L5.MRK_prices            0.004486         0.025635            0.175           0.861
# L5.MRK_sentiment        -0.001156         0.000562           -2.055           0.040
# L6.MRK_prices           -0.046754         0.025652           -1.823           0.068
# L6.MRK_sentiment        -0.000761         0.000552           -1.380           0.168
# ===================================================================================
#
# Results for equation MRK_sentiment
# ===================================================================================
#                       coefficient       std. error           t-stat            prob
# -----------------------------------------------------------------------------------
# const                    0.017635         0.014894            1.184           0.236
# L1.MRK_prices           -0.021931         1.207918           -0.018           0.986
# L1.MRK_sentiment        -0.225316         0.025867           -8.711           0.000
# L2.MRK_prices           -0.691369         1.206548           -0.573           0.567
# L2.MRK_sentiment        -0.142621         0.026448           -5.393           0.000
# L3.MRK_prices           -1.426590         1.208326           -1.181           0.238
# L3.MRK_sentiment        -0.095074         0.026645           -3.568           0.000
# L4.MRK_prices            0.655108         1.208786            0.542           0.588
# L4.MRK_sentiment        -0.069540         0.026679           -2.607           0.009
# L5.MRK_prices            0.651444         1.206746            0.540           0.589
# L5.MRK_sentiment        -0.076220         0.026472           -2.879           0.004
# L6.MRK_prices           -0.362006         1.207514           -0.300           0.764
# L6.MRK_sentiment        -0.077080         0.025965           -2.969           0.003
# ===================================================================================
#
# Correlation matrix of residuals
#                  MRK_prices  MRK_sentiment
# MRK_prices         1.000000       0.008502
# MRK_sentiment      0.008502       1.000000
#
#
#
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Sun, 25, Dec, 2022
# Time:                     00:04:44
# --------------------------------------------------------------------
# No. of Equations:         2.00000    BIC:                   -10.2078
# Nobs:                     1489.00    HQIC:                  -10.3554
# Log likelihood:           3615.23    FPE:                2.91514e-05
# AIC:                     -10.4430    Det(Omega_mle):     2.79010e-05
# --------------------------------------------------------------------
# Results for equation PFE_prices
# ====================================================================================
#                        coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------------
# const                     0.000410         0.000292            1.405           0.160
# L1.PFE_prices             0.038749         0.026195            1.479           0.139
# L1.PFE_sentiment         -0.000044         0.000611           -0.072           0.942
# L2.PFE_prices            -0.002224         0.026298           -0.085           0.933
# L2.PFE_sentiment          0.000921         0.000630            1.463           0.144
# L3.PFE_prices            -0.010881         0.026219           -0.415           0.678
# L3.PFE_sentiment         -0.000536         0.000636           -0.843           0.399
# L4.PFE_prices            -0.044535         0.026248           -1.697           0.090
# L4.PFE_sentiment         -0.000673         0.000643           -1.046           0.295
# L5.PFE_prices             0.007222         0.026274            0.275           0.783
# L5.PFE_sentiment          0.000750         0.000646            1.162           0.245
# L6.PFE_prices            -0.051987         0.026231           -1.982           0.047
# L6.PFE_sentiment         -0.000082         0.000641           -0.128           0.898
# L7.PFE_prices             0.010749         0.026262            0.409           0.682
# L7.PFE_sentiment         -0.000786         0.000639           -1.228           0.219
# L8.PFE_prices            -0.035309         0.026212           -1.347           0.178
# L8.PFE_sentiment         -0.000042         0.000641           -0.066           0.947
# L9.PFE_prices            -0.024899         0.026232           -0.949           0.343
# L9.PFE_sentiment          0.001428         0.000640            2.231           0.026
# L10.PFE_prices           -0.009209         0.026244           -0.351           0.726
# L10.PFE_sentiment         0.000308         0.000640            0.481           0.630
# L11.PFE_prices            0.024054         0.026214            0.918           0.359
# L11.PFE_sentiment         0.000876         0.000640            1.368           0.171
# L12.PFE_prices           -0.007496         0.026201           -0.286           0.775
# L12.PFE_sentiment         0.000005         0.000646            0.009           0.993
# L13.PFE_prices           -0.016886         0.026170           -0.645           0.519
# L13.PFE_sentiment         0.000050         0.000645            0.077           0.938
# L14.PFE_prices           -0.030657         0.026208           -1.170           0.242
# L14.PFE_sentiment        -0.000437         0.000637           -0.686           0.492
# L15.PFE_prices           -0.008247         0.026177           -0.315           0.753
# L15.PFE_sentiment        -0.000105         0.000631           -0.167           0.868
# L16.PFE_prices            0.043753         0.026164            1.672           0.094
# L16.PFE_sentiment        -0.000197         0.000612           -0.322           0.747
# ====================================================================================
#
# Results for equation PFE_sentiment
# ====================================================================================
#                        coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------------
# const                    -0.003060         0.012427           -0.246           0.806
# L1.PFE_prices             3.815766         1.114976            3.422           0.001
# L1.PFE_sentiment         -0.253421         0.026000           -9.747           0.000
# L2.PFE_prices             0.081397         1.119336            0.073           0.942
# L2.PFE_sentiment         -0.155736         0.026795           -5.812           0.000
# L3.PFE_prices             2.218096         1.115997            1.988           0.047
# L3.PFE_sentiment         -0.177649         0.027087           -6.558           0.000
# L4.PFE_prices            -0.590775         1.117225           -0.529           0.597
# L4.PFE_sentiment         -0.151746         0.027370           -5.544           0.000
# L5.PFE_prices             0.869624         1.118319            0.778           0.437
# L5.PFE_sentiment         -0.102463         0.027485           -3.728           0.000
# L6.PFE_prices            -0.281696         1.116505           -0.252           0.801
# L6.PFE_sentiment         -0.101136         0.027290           -3.706           0.000
# L7.PFE_prices             0.104288         1.117813            0.093           0.926
# L7.PFE_sentiment         -0.090542         0.027219           -3.326           0.001
# L8.PFE_prices            -1.804263         1.115671           -1.617           0.106
# L8.PFE_sentiment         -0.143667         0.027285           -5.265           0.000
# L9.PFE_prices            -0.259434         1.116511           -0.232           0.816
# L9.PFE_sentiment         -0.049716         0.027252           -1.824           0.068
# L10.PFE_prices           -1.021209         1.117062           -0.914           0.361
# L10.PFE_sentiment        -0.114193         0.027225           -4.194           0.000
# L11.PFE_prices            0.519318         1.115769            0.465           0.642
# L11.PFE_sentiment        -0.160806         0.027261           -5.899           0.000
# L12.PFE_prices           -0.147788         1.115193           -0.133           0.895
# L12.PFE_sentiment        -0.113746         0.027492           -4.137           0.000
# L13.PFE_prices           -2.574688         1.113914           -2.311           0.021
# L13.PFE_sentiment        -0.059018         0.027433           -2.151           0.031
# L14.PFE_prices           -0.650615         1.115494           -0.583           0.560
# L14.PFE_sentiment        -0.055880         0.027110           -2.061           0.039
# L15.PFE_prices            0.294319         1.114192            0.264           0.792
# L15.PFE_sentiment        -0.054598         0.026858           -2.033           0.042
# L16.PFE_prices           -1.597419         1.113646           -1.434           0.151
# L16.PFE_sentiment        -0.133538         0.026044           -5.127           0.000
# ====================================================================================
#
# Correlation matrix of residuals
#                  PFE_prices  PFE_sentiment
# PFE_prices         1.000000       0.066319
# PFE_sentiment      0.066319       1.000000

# %% [markdown]
# # Testing asssumptions

# %% [markdown]
# ### Assumption 1
# The mean of the residuals should be approximately zero:

# %%
for result in results:
    sentiment = result.names[0]
    price = result.names[1]
    print(f"{sentiment} resid. mean = ",result.resid[sentiment].mean())
    print(f"{price} resid. mean = ", result.resid[price].mean())
# Out:
# AAPL_prices resid. mean =  -4.185659861606237e-18
# AAPL_sentiment resid. mean =  -2.6669164344883115e-16
# MSFT_prices resid. mean =  1.752198863578991e-18
# MSFT_sentiment resid. mean =  -1.3361448355461924e-16
# BAC_prices resid. mean =  -2.0552827840792592e-18
# BAC_sentiment resid. mean =  3.792089316931822e-17
# AMZN_prices resid. mean =  7.792340747703305e-19
# AMZN_sentiment resid. mean =  -1.4628821030355003e-15
# TSLA_prices resid. mean =  -5.547416845228963e-19
# TSLA_sentiment resid. mean =  -2.0828701114886347e-16
# XOM_prices resid. mean =  8.604228440844963e-19
# XOM_sentiment resid. mean =  1.9895196601282806e-16
# JPM_prices resid. mean =  6.79558563540548e-19
# JPM_sentiment resid. mean =  -1.3017938196803967e-17
# KO_prices resid. mean =  -1.0012031284194799e-18
# KO_sentiment resid. mean =  1.1391466705572748e-16
# WMT_prices resid. mean =  1.5173048003210473e-18
# WMT_sentiment resid. mean =  1.0421293457814803e-16
# CVX_prices resid. mean =  -6.312304822283499e-19
# CVX_sentiment resid. mean =  -9.267948727305654e-17
# JNJ_prices resid. mean =  3.7056843278543277e-19
# JNJ_sentiment resid. mean =  5.929094924566924e-19
# HD_prices resid. mean =  1.8503717077085944e-19
# HD_sentiment resid. mean =  -7.105427357601002e-18
# PG_prices resid. mean =  -2.169273444908873e-18
# PG_sentiment resid. mean =  1.5541639080858238e-15
# MRK_prices resid. mean =  -5.4252059075245304e-18
# MRK_sentiment resid. mean =  -1.749101197434803e-15
# PFE_prices resid. mean =  1.7894796904636505e-18
# PFE_sentiment resid. mean =  1.3122851063400104e-16

# %% [markdown]
# ### Assumption 2

# %% [markdown]
# Covariance matrix of the errors should be positive semi definite:

# %%
for result in results:
    cov_matrix = result.resid_corr
    print(linalg.eigvals(cov_matrix))
# Out:
# [1.04662188 0.95337812]
# [1.00788712 0.99211288]
# [0.92905974 1.07094026]
# [1.05375535 0.94624465]
# [0.96468457 1.03531543]
# [1.04088217 0.95911783]
# [1.00378321 0.99621679]
# [1.01153468 0.98846532]
# [1.09339304 0.90660696]
# [1.01914048 0.98085952]
# [1.03034024 0.96965976]
# [0.92115693 1.07884307]
# [1.03233171 0.96766829]
# [0.99149771 1.00850229]
# [1.06631872 0.93368128]

# %% [markdown]
# ### Assumption 3

# %% [markdown]
# Residuals should be uncorrelated:

# %%
for result in results:
    print(f"{result.names[0]} and {result.names[1]}:")
    print(result.test_whiteness(result.k_ar+1).summary(), "\n \n")
# Out:
# AAPL_prices and AAPL_sentiment:
# Portmanteau-test for residual autocorrelation. H_0: residual autocorrelation up to lag 14 is zero. Conclusion: fail to reject H_0 at 5% significance level.
# ========================================
# Test statistic Critical value p-value df
# ----------------------------------------
#          2.813          9.488   0.590  4
# ----------------------------------------
#
#
# MSFT_prices and MSFT_sentiment:
# Portmanteau-test for residual autocorrelation. H_0: residual autocorrelation up to lag 17 is zero. Conclusion: fail to reject H_0 at 5% significance level.
# ========================================
# Test statistic Critical value p-value df
# ----------------------------------------
#          9.042          9.488   0.060  4
# ----------------------------------------
#
#
# BAC_prices and BAC_sentiment:
# Portmanteau-test for residual autocorrelation. H_0: residual autocorrelation up to lag 7 is zero. Conclusion: fail to reject H_0 at 5% significance level.
# ========================================
# Test statistic Critical value p-value df
# ----------------------------------------
#          2.642          9.488   0.619  4
# ----------------------------------------
#
#
# AMZN_prices and AMZN_sentiment:
# Portmanteau-test for residual autocorrelation. H_0: residual autocorrelation up to lag 10 is zero. Conclusion: fail to reject H_0 at 5% significance level.
# ========================================
# Test statistic Critical value p-value df
# ----------------------------------------
#          2.712          9.488   0.607  4
# ----------------------------------------
#
#
# TSLA_prices and TSLA_sentiment:
# Portmanteau-test for residual autocorrelation. H_0: residual autocorrelation up to lag 5 is zero. Conclusion: fail to reject H_0 at 5% significance level.
# ========================================
# Test statistic Critical value p-value df
# ----------------------------------------
#          1.764          9.488   0.779  4
# ----------------------------------------
#
#
# XOM_prices and XOM_sentiment:
# Portmanteau-test for residual autocorrelation. H_0: residual autocorrelation up to lag 6 is zero. Conclusion: fail to reject H_0 at 5% significance level.
# ========================================
# Test statistic Critical value p-value df
# ----------------------------------------
#          6.003          9.488   0.199  4
# ----------------------------------------
#
#
# JPM_prices and JPM_sentiment:
# Portmanteau-test for residual autocorrelation. H_0: residual autocorrelation up to lag 5 is zero. Conclusion: fail to reject H_0 at 5% significance level.
# ========================================
# Test statistic Critical value p-value df
# ----------------------------------------
#          7.769          9.488   0.100  4
# ----------------------------------------
#
#
# KO_prices and KO_sentiment:
# Portmanteau-test for residual autocorrelation. H_0: residual autocorrelation up to lag 9 is zero. Conclusion: fail to reject H_0 at 5% significance level.
# ========================================
# Test statistic Critical value p-value df
# ----------------------------------------
#          8.092          9.488   0.088  4
# ----------------------------------------
#
#
# WMT_prices and WMT_sentiment:
# Portmanteau-test for residual autocorrelation. H_0: residual autocorrelation up to lag 6 is zero. Conclusion: fail to reject H_0 at 5% significance level.
# ========================================
# Test statistic Critical value p-value df
# ----------------------------------------
#          6.034          9.488   0.197  4
# ----------------------------------------
#
#
# CVX_prices and CVX_sentiment:
# Portmanteau-test for residual autocorrelation. H_0: residual autocorrelation up to lag 11 is zero. Conclusion: reject H_0 at 5% significance level.
# ========================================
# Test statistic Critical value p-value df
# ----------------------------------------
#          9.861          9.488   0.043  4
# ----------------------------------------
#
#
# JNJ_prices and JNJ_sentiment:
# Portmanteau-test for residual autocorrelation. H_0: residual autocorrelation up to lag 8 is zero. Conclusion: fail to reject H_0 at 5% significance level.
# ========================================
# Test statistic Critical value p-value df
# ----------------------------------------
#          6.652          9.488   0.155  4
# ----------------------------------------
#
#
# HD_prices and HD_sentiment:
# Portmanteau-test for residual autocorrelation. H_0: residual autocorrelation up to lag 6 is zero. Conclusion: fail to reject H_0 at 5% significance level.
# ========================================
# Test statistic Critical value p-value df
# ----------------------------------------
#          4.753          9.488   0.314  4
# ----------------------------------------
#
#
# PG_prices and PG_sentiment:
# Portmanteau-test for residual autocorrelation. H_0: residual autocorrelation up to lag 9 is zero. Conclusion: fail to reject H_0 at 5% significance level.
# ========================================
# Test statistic Critical value p-value df
# ----------------------------------------
#          1.613          9.488   0.806  4
# ----------------------------------------
#
#
# MRK_prices and MRK_sentiment:
# Portmanteau-test for residual autocorrelation. H_0: residual autocorrelation up to lag 7 is zero. Conclusion: fail to reject H_0 at 5% significance level.
# ========================================
# Test statistic Critical value p-value df
# ----------------------------------------
#          3.169          9.488   0.530  4
# ----------------------------------------
#
#
# PFE_prices and PFE_sentiment:
# Portmanteau-test for residual autocorrelation. H_0: residual autocorrelation up to lag 17 is zero. Conclusion: fail to reject H_0 at 5% significance level.
# ========================================
# Test statistic Critical value p-value df
# ----------------------------------------
#          6.876          9.488   0.143  4
# ----------------------------------------

# %% [markdown]
# ### Assumption 4

# %% [markdown]
# Data should be normally distributed:

# %%
for result in results:
    print(result.test_normality().summary())
# Out:
# normality (skew and kurtosis) test. H_0: data generated by normally-distributed process. Conclusion: reject H_0 at 5% significance level.
# ========================================
# Test statistic Critical value p-value df
# ----------------------------------------
#      1.876e+04          9.488   0.000  4
# ----------------------------------------
# normality (skew and kurtosis) test. H_0: data generated by normally-distributed process. Conclusion: reject H_0 at 5% significance level.
# ========================================
# Test statistic Critical value p-value df
# ----------------------------------------
#      1.066e+05          9.488   0.000  4
# ----------------------------------------
# normality (skew and kurtosis) test. H_0: data generated by normally-distributed process. Conclusion: reject H_0 at 5% significance level.
# ========================================
# Test statistic Critical value p-value df
# ----------------------------------------
#          1889.          9.488   0.000  4
# ----------------------------------------
# normality (skew and kurtosis) test. H_0: data generated by normally-distributed process. Conclusion: reject H_0 at 5% significance level.
# ========================================
# Test statistic Critical value p-value df
# ----------------------------------------
#      3.133e+04          9.488   0.000  4
# ----------------------------------------
# normality (skew and kurtosis) test. H_0: data generated by normally-distributed process. Conclusion: reject H_0 at 5% significance level.
# ========================================
# Test statistic Critical value p-value df
# ----------------------------------------
#          5411.          9.488   0.000  4
# ----------------------------------------
# normality (skew and kurtosis) test. H_0: data generated by normally-distributed process. Conclusion: reject H_0 at 5% significance level.
# ========================================
# Test statistic Critical value p-value df
# ----------------------------------------
#          870.9          9.488   0.000  4
# ----------------------------------------
# normality (skew and kurtosis) test. H_0: data generated by normally-distributed process. Conclusion: reject H_0 at 5% significance level.
# ========================================
# Test statistic Critical value p-value df
# ----------------------------------------
#          1029.          9.488   0.000  4
# ----------------------------------------
# normality (skew and kurtosis) test. H_0: data generated by normally-distributed process. Conclusion: reject H_0 at 5% significance level.
# ========================================
# Test statistic Critical value p-value df
# ----------------------------------------
#          8481.          9.488   0.000  4
# ----------------------------------------
# normality (skew and kurtosis) test. H_0: data generated by normally-distributed process. Conclusion: reject H_0 at 5% significance level.
# ========================================
# Test statistic Critical value p-value df
# ----------------------------------------
#      2.040e+04          9.488   0.000  4
# ----------------------------------------
# normality (skew and kurtosis) test. H_0: data generated by normally-distributed process. Conclusion: reject H_0 at 5% significance level.
# ========================================
# Test statistic Critical value p-value df
# ----------------------------------------
#          1683.          9.488   0.000  4
# ----------------------------------------
# normality (skew and kurtosis) test. H_0: data generated by normally-distributed process. Conclusion: reject H_0 at 5% significance level.
# ========================================
# Test statistic Critical value p-value df
# ----------------------------------------
#      1.041e+04          9.488   0.000  4
# ----------------------------------------
# normality (skew and kurtosis) test. H_0: data generated by normally-distributed process. Conclusion: reject H_0 at 5% significance level.
# ========================================
# Test statistic Critical value p-value df
# ----------------------------------------
#      5.739e+04          9.488   0.000  4
# ----------------------------------------
# normality (skew and kurtosis) test. H_0: data generated by normally-distributed process. Conclusion: reject H_0 at 5% significance level.
# ========================================
# Test statistic Critical value p-value df
# ----------------------------------------
#      2.562e+04          9.488   0.000  4
# ----------------------------------------
# normality (skew and kurtosis) test. H_0: data generated by normally-distributed process. Conclusion: reject H_0 at 5% significance level.
# ========================================
# Test statistic Critical value p-value df
# ----------------------------------------
#      1.132e+04          9.488   0.000  4
# ----------------------------------------
# normality (skew and kurtosis) test. H_0: data generated by normally-distributed process. Conclusion: reject H_0 at 5% significance level.
# ========================================
# Test statistic Critical value p-value df
# ----------------------------------------
#          9807.          9.488   0.000  4
# ----------------------------------------

# %% [markdown]
# Assumption 3 and 4 are not met for most stocks. Let's still try to forecast.

# %% [markdown]
# # Forecasting

# %%
def forecast(results, merged_df) -> tuple:
    """Forecast result of the VAR fit 14 timesteps ahead using prior sentiment and price
    data."""

    # get ticker name by removing "_prices"
    ticker = results.names[0][:-7]

    # last date in train set: 2019-12-30
    # downloading testset
    test_prices = pd.DataFrame(yf.Ticker(ticker).history(start = '2019-12-31', end = '2020-1-20')['Close'])

    forecast_df = pd.DataFrame(results.forecast(np.array(merged_df), 13))
    forecast_df.columns = ['price', 'sentiment']

    # recall stock price is percent change, and sentiment is differences
    # undoing the differencing of APPL_sentiment by taking the cumsum
    initial_value = test_prices.iloc[0,:]
    forecast_df["sentiment"].cumsum(axis = 0)
    forecasted_prices = forecast_df.assign(price=forecast_df.price.pct_change(-1)+initial_value[0])
    forecasted_prices['price'].index = test_prices.index

    return forecasted_prices, test_prices

# %%
fig = plt.figure(figsize = (18, 20))
i = 0
for result, merged_df in zip(results, merged_dfs):
    i+=1
    forecasted, real_prices = forecast(result, merged_df)
    plt.subplot(5, 3, i)
    plt.title(f"{result.names[0]} ({result.k_ar} lags)" )
    plt.xlabel('day')
    plt.ylabel('Stock price (USD')
    days = real_prices.index
    plt.plot(days, real_prices["Close"], label='real prices')
    plt.plot(days, forecasted["price"], label='forecast')
    plt.xticks(rotation=55)
    plt.legend()
fig.tight_layout(pad = 3)
plt.show()

# %% [markdown]
# # Using sliding windows for forecast

# %% [markdown]
# We can observe in the graphs above that the forecast is of moderate quality. Let's try another tactic: dividing the data in windows and fitting each to the VAR model,
# to generate multiple predictions per stock. First we test this sliding window method one stock.

# %%
def sliding_windows(df, window_size) -> list:
    """Create sliding windows of timeseries for each variable in the dataframe"""

    list_of_windows_per_variable = []
    for variable in df.columns:
        variable_timeseries = df[str(variable)]
        windows = []

        # Iterate over the time series
        for i in np.arange(len(variable_timeseries.index) - window_size + 1, step = window_size):

            # Take the last `window_size` elements of the time series
            # windows are non overlapping, i.e. the first window is from index 0-20, the next from 20-40 etc.
            current_window = variable_timeseries[i : i+window_size]
            window_index = variable_timeseries.index[i : i+window_size]
            # Add the current window to the list of windows
            windows.append(pd.DataFrame(current_window, index = window_index))
        list_of_windows_per_variable.append(windows)

    return list_of_windows_per_variable

# %%
# Sliding windows for AAPL
windows = sliding_windows(merged_dfs[0], window_size = 78)
windows_prices = windows[0]
windows_sentiment = windows[1]

# %%
def VAR_model_windows(windows):
    """Return a tuple containing a list of the VAR models of all windows and a list of
    merged prices/sentiment dataframes."""

    merged_windows = []
    VAR_models = []
    for window_prices, window_sentiments in zip(windows[0], windows[1]):
        merged_window = pd.merge(window_prices, window_sentiments, left_index= True, right_index = True)
        merged_windows.append(merged_window)
        VAR_models.append(VAR(merged_window))

    return VAR_models, merged_windows

# %%
var_models_windows, merged_windows = VAR_model_windows(windows)

window_results = []
for model in var_models_windows:
    result = model.fit(13)
    window_results.append(result)

# %%
def forecast_windows(window_results: list, merged_windows: list) -> tuple:
    """Returns a tuple of a list containing forecasted prices for all windows and a
    list of the real prices"""

    forecasted_prices = []
    for result, merged_df in zip(window_results, merged_windows):
        forecasted, real_prices = forecast(result, merged_df)
        forecasted_prices.append(forecasted["price"])
        days = real_prices.index

    return forecasted_prices, real_prices


def plot_forecasts(forecasted_prices: list, real_prices: pd.DataFrame):
    """Plot the forecasts of all windows and the real prices in one figure."""

    days = real_prices.index

    for forecast in forecasted_prices:
        line1, = plt.plot(days, forecast, label='forecast', color="blue", alpha=0.4)

    line2, = plt.plot(days, real_prices["Close"], label='real prices', color = "red")
    plt.title(f"{result.names[0]} ({result.k_ar} lags)" )
    plt.xticks(rotation=55)
    plt.xlabel('day')
    plt.ylabel('Stock price (USD')
    plt.legend([line1, line2], ["Forecast", "Real price"])
    plt.show()

# %%
forecasted_prices, real_prices = forecast_windows(window_results, merged_windows)
plot_forecasts(forecasted_prices, real_prices)

# %%
def mean_forecasts(forecasted_prices: list) -> tuple:
    """Compute the mean and 95% confidence interval of the window forecasts per timepoint"""

    df_mean = pd.concat(forecasted_prices, axis=1).agg(['mean'], axis=1)
    df = pd.DataFrame(forecasted_prices)
    df_percentiles = pd.DataFrame()
    for date in df:
        df_percentiles[date] = [np.percentile(df[date], 2.5), np.percentile(df[date], 97.5)]
    df_percentiles = df_percentiles.T
    df_percentiles.columns = ["Upper 95% CL", "Lower 95% CL"]

    return df_mean, df_percentiles


def plot_mean_forecasts(
    df_mean: pd.DataFrame,
    df_percentiles: pd.DataFrame,
    real_prices: pd.DataFrame
    ):

    df_percentiles.plot(style="--", color="red")
    df_mean["mean"].plot(label = "Mean forecast")
    real_prices["Close"].plot(label = "Real price")

    plt.legend()
    plt.ylabel("Stock price (USD)")
    plt.xlabel("Date")
    plt.show()

# %%
df_mean, df_percentiles = mean_forecasts(forecasted_prices)
plot_mean_forecasts(df_mean, df_percentiles, real_prices)

# %% [markdown]
# # Assumption tests of sliding windows

# %% [markdown]
# ### All 4 assumption tests:

# %%
def normallity_of_residuals(result) -> bool:
    """
    This function tests the normality of residuals, given these residuals and returns
    the p value. Test using significance of alpha = 0.05
    """

    p_value = pd.DataFrame(result.test_normality().summary().data).iloc[1,2]
    if p_value < 0.05:
            significant_p = True
    else:
            significant_p = False
    return significant_p


def autocorrelation_of_residuals(result) -> bool:
    """
    This function tests the autocOrrelation of residuals, given these residuals and
    returns the p values
    """

    p_value = pd.DataFrame(result.test_whiteness(result.k_ar+1).summary().data).iloc[1,2]
    if p_value < 0.05:
            significant_p = True
    else:
            significant_p = False
    return significant_p


def check_mean_of_residuals(result) -> tuple:
    """
    checking if residuals of a VAR results containing the residuals of 2 respective
    timeseries have mean 0 and returns a tuple containing boolean values.

    ref: https://en.wikipedia.org/wiki/Vector_autoregression
    """
    sentiment = result.names[0]
    price = result.names[1]
    if result.resid[sentiment].mean() < 0.001:
        sentiment_timeseries_residual_mean_of_0 = True
    if result.resid[price].mean() < 0.001:
        price_timeseries_residual_mean_of_0 = True
    if sentiment_timeseries_residual_mean_of_0 and price_timeseries_residual_mean_of_0:
        return True
    else:
        return False

def matrix_is_postivive_and_semidefinite(matrix) -> bool:
    """
    checking if covariance matrix is positive and semi-definite. This can be checked by
    checking of the matrix is symetric and eigenvalues are positive.

    ref: https://en.wikipedia.org/wiki/Definite_matrix
    """

    cov_matrix = result.resid_corr
    cov_matrix = result.resid_corr
    is_symmetric = cov_matrix.shape[0] == cov_matrix.shape[1]
    eigen_values = linalg.eigvals(cov_matrix)
    eigen_values_positive = eigen_values[0]> 0 and eigen_values[1] > 0
    if is_symmetric and eigen_values_positive:
        covariance_matrix_positive_and_semi_definite = True
    else:
        covariance_matrix_positive_and_semi_definite = False
    return covariance_matrix_positive_and_semi_definite

# %% [markdown]
# Let's use these function to make one assumption matrix:

# %%
def Assumption_matrix(window_results: list) -> pd.DataFrame:
    """Creates a dataframe of assumption test results per window, where true is the value
    if the assumption passes and False when it does not"""

    assumption_test_dict = {}
    for i, window_result in enumerate(window_results):
        stock_name = f"{window_result.names[0]}_window_{i}"
        dict_of_assumption_test_results = {str(stock_name):
        {
            'Mean of residuals = 0':check_mean_of_residuals(window_result),
            'Autocorrelation of residuals = 0': autocorrelation_of_residuals(window_result),
            'Covariance Matrix positive and semidefinite':matrix_is_postivive_and_semidefinite(window_result),
            'normality of residuals':normallity_of_residuals(window_result)}
            }
        assumption_test_dict.update(dict_of_assumption_test_results)

    return pd.DataFrame(assumption_test_dict)

# %%
def plot_assumptions(matrix: pd.DataFrame):
    """Plot the assumption matrix for all windows of a specific stock"""

    fig, ax = plt.subplots(1,1)
    cmap = (mpl.colors.ListedColormap(['red', 'green']))
    ax.imshow(matrix, cmap=cmap)
    ax.set_yticks(range(4))
    ax.set_xticks(range(19))
    ax.set_yticklabels([
        "Error mean = 0",
        "Residual Autocorrelation = 0",
        "Covariance matrix positive and semi definite",
        "Normality of residual"
        ])
    plt.xlabel("window")
    plt.ylabel("test")
    plt.title(f"{window_results[0].names[0]}")
    plt.show()

# %%
matrix = Assumption_matrix(window_results)
plot_assumptions(matrix)

# %% [markdown]
# # Forecast and assumption test for all stocks

# %%
lags_stocks = [result.k_ar for result in results]
lags_stocks
# Out:
# [13, 16, 6, 9, 4, 5, 4, 8, 5, 10, 7, 5, 8, 6, 16]

# %%
all_forecasts = []
all_real_prices = []
for i, merged_df in enumerate(merged_dfs):

    # Make VAR models from sliding windows
    windows = sliding_windows(merged_df, window_size = 78)
    var_models_windows, merged_windows = VAR_model_windows(windows)

    # Fit the VAR models
    window_results = []
    for model in var_models_windows:
        result = model.fit(lags_stocks[i])
        window_results.append(result)

    matrix = Assumption_matrix(window_results)
    plot_assumptions(matrix)

    # Get the forecasted prices and plot the forecast for each window
    forecasted_prices, real_prices = forecast_windows(window_results, merged_windows)
    plot_forecasts(forecasted_prices, real_prices)

    all_forecasts.append(forecasted_prices)
    all_real_prices.append(real_prices)

    mean_forecast, df_percentiles = mean_forecasts(forecasted_prices)
    plot_mean_forecasts(mean_forecast, df_percentiles, real_prices)
    print("================================================================")
# Out:
# ================================================================
# ================================================================
# ================================================================
# ================================================================
# ================================================================
# ================================================================
# ================================================================
# ================================================================
# ================================================================
# ================================================================
# ================================================================
# ================================================================
# ================================================================
# ================================================================
# ================================================================

# %% [markdown]
# # Residual analysis

# %% [markdown]
# To say something about the quality of the prediction we need a quantative measure. Let's use the root-mean-squared-error (RMSE) of the prediction relative to the real prices for this.

# %%
stock_names = [result.names[0] for result in results]
print(stock_names)
# Out:
# ['AAPL_prices', 'MSFT_prices', 'BAC_prices', 'AMZN_prices', 'TSLA_prices', 'XOM_prices', 'JPM_prices', 'KO_prices', 'WMT_prices', 'CVX_prices', 'JNJ_prices', 'HD_prices', 'PG_prices', 'MRK_prices', 'PFE_prices']

# %%
def RMSE(forecasted_prices, real_prices)-> tuple[list, list]:
    """Return the Root-mean-squared and the residuals over time of the forecasted prices
    relative to the real prices"""

    forecasted_prices = forecasted_prices.values
    real_prices = real_prices.values
    sqr_resid = [(real_prices[i]-forecasted_prices[i])**2 for i in range(len(forecasted_prices)-1)]
    RMSE = (np.mean(sqr_resid))**0.5

    return RMSE, np.sqrt(sqr_resid)

# %%
RMSE_stocks = []
for stock_forecast, real_prices in zip(all_forecasts, all_real_prices):
    RMSE_windows = [RMSE(stock_forecast[i], real_prices["Close"])[0] for i in range(len(stock_forecast))]
    RMSE_stocks.append(RMSE_windows)

# %%
means = [np.mean(RMSE_windows) for RMSE_windows in RMSE_stocks]
errors = [[np.percentile(RMSE_windows, 2.5), np.percentile(RMSE_windows, 97.5)] for RMSE_windows in RMSE_stocks]


index = [i for i in range(len(means))]

fig, ax = plt.subplots(1,1)
ax.plot(index, means, ".")
ax.set_xticks(range(15))
ax.set_xticklabels([stock_name[:-7] for stock_name in stock_names], rotation =35)
plt.xlabel("stock")
plt.ylabel("RMSE (USD)")
plt.ylim(0, 60)
for i, error in enumerate(errors):
    plt.vlines(i, ymin = error[0], ymax = error[1], linestyles="dashed")
plt.show()

# %% [markdown]
# We can also look at the average residuals over time for all the stocks to get a better sense of the quality of our model.

# %%
resids_stocks = []
i = 1
fig = plt.figure(figsize=(25,20))
for stock_forecast, real_prices in zip(all_forecasts, all_real_prices):

    # Compute the residuals for each window and put it in a 2D array
    resids_windows = np.array([RMSE(stock_forecast[i], real_prices["Close"])[1] for i in range(len(stock_forecast))])

    # Compute average the residuals over all windows
    mean_resids_stock = np.average(resids_windows, axis=0)

    dates = stock_forecast[0].index[0 :-1] # Last date no data for the forecast.

    plt.subplot(5, 3, i)
    plt.plot(dates, mean_resids_stock)
    plt.xticks(rotation=30)
    plt.title(f"{stock_names[i-1]}")
    plt.xlabel("Date")
    plt.ylabel("Average Residual (USD)")
    i += 1

fig.tight_layout()
plt.show()

# %% [markdown]
# The residuals over time do not agree with what we expect from a timeseries prediction, namely that the residuals increase over time.

# %% [markdown]
# # Residuals original forecast (without windows)

# %% [markdown]
# It is usefull to do the same for the forecast without windows, so we can compare the quality of prediction of the two.

# %%
original_forecasts = []
fig = plt.figure(figsize = (18, 20))
i = 0
for result, merged_df in zip(results, merged_dfs):
    i+=1
    forecasted, real_prices = forecast(result, merged_df)
    original_forecasts.append(forecasted)
    residuals = RMSE(forecasted["price"], real_prices["Close"])[1]
    plt.subplot(5, 3, i)
    plt.title(f"{result.names[0]} ({result.k_ar} lags)" )
    plt.xlabel('date')
    plt.ylabel('Residual (USD)')
    days = real_prices.index[:-1] # Last date no data for forecast
    plt.plot(days, residuals)
    plt.xticks(rotation=55)
fig.tight_layout(pad = 3)
plt.show()

# %%
means_orig = [RMSE(original_forecasts[i], all_real_prices[i])[0] for i in range(len(original_forecasts))]
stock_names = [stock_name[:-7] for stock_name in stock_names]

fig, ax = plt.subplots(1,1)
label = "_nolegend_"
for i, error in enumerate(errors):
    if i == len(errors)-1:
        label = "95 % CL"
    plt.vlines(i, ymin = error[0], ymax = error[1], linestyles="dashed", linewidth=2.5, label=label)
ax.plot(index, means, ".", markersize = 14, label = "Multi window RMSE mean")
ax.plot(index, means_orig, '.', markersize = 14, label = "Whole time range RMSE")
ax.grid()
ax.set_xticks(range(15))
ax.set_xticklabels(stock_names, rotation =35)
plt.xlabel("stock")
plt.ylabel("RMSE (USD)")
plt.title("Comparing RMSE's")
plt.ylim(0, 200)
plt.legend()
plt.show()

# %% [markdown]
# We can observe in the plot above, that the prediction gets significantly better when using a sliding window instead of the whole time range.

# %%
df = pd.DataFrame(index= ["Mean_RMSE", "CL"],  columns = stock_names)
for i, stock in enumerate(stock_names):
    df[stock] = [means[i], errors[i]]
df
# Out:
#                                               AAPL  \
# Mean_RMSE                                19.673295
# CL         [3.680347804733857, 126.50416736439037]
#
#                                                MSFT  \
# Mean_RMSE                                  7.242925
# CL         [4.4630752773943945, 13.820740450314357]
#
#                                                 BAC  \
# Mean_RMSE                                   9.15319
# CL         [0.5849698167410442, 46.070350992928525]
#
#                                               AMZN  \
# Mean_RMSE                                11.433143
# CL         [1.8546244935809613, 67.81594356695904]
#
#                                               TSLA  \
# Mean_RMSE                                 7.644425
# CL         [4.801333202731442, 17.373764224744555]
#
#                                                XOM  \
# Mean_RMSE                                10.142784
# CL         [2.3974719278319694, 56.31346925966167]
#
#                                                 JPM  \
# Mean_RMSE                                 34.977013
# CL         [1.3397149236333488, 288.23325507448794]
#
#                                                 KO  \
# Mean_RMSE                                26.296828
# CL         [1.712204425374152, 114.65831404158259]
#
#                                                 WMT  \
# Mean_RMSE                                  5.572237
# CL         [2.2585414254562717, 22.742454582668877]
#
#                                               CVX  \
# Mean_RMSE                               12.161317
# CL         [2.872127841436363, 56.92113512997777]
#
#                                                JNJ  \
# Mean_RMSE                                 6.556825
# CL         [1.4180702228902309, 21.66415466500737]
#
#                                                 HD  \
# Mean_RMSE                                 6.709487
# CL         [4.443799142245405, 16.750913911113283]
#
#                                                 PG  \
# Mean_RMSE                                 6.411196
# CL         [2.152402445344576, 24.286248137777612]
#
#                                                MRK  \
# Mean_RMSE                                14.424365
# CL         [1.4531867596316093, 88.15394118440096]
#
#                                               PFE
# Mean_RMSE                              205.204757
# CL         [2.342101780936736, 2076.302900208737]

# %%
df.to_csv("../data/RMSE_var.csv")
